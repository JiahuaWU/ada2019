# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Get the health data to analyze the relation between food and health

# %% [markdown]
# 1. Get lifespan data in different countries from WHO website

# %%
data= pd.read_csv('data/data_health/RAW_lifespan.csv')

# %%
data_lifespan = data[data['Indicator']=='Life expectancy at birth (years)']
data_lifespan = data_lifespan[data_lifespan['Dim1'] == 'Both sexes']
data_lifespan.drop(columns=['Indicator','Period','Dim1'],inplace=True)
data_lifespan.rename(columns={'First Tooltip':'Life span'},inplace=True)
data_lifespan
# Out:
#                                 Location  Life span
# 0                            Afghanistan      62.69
# 12                               Albania      76.37
# 24                               Algeria      76.36
# 36                                Angola      62.63
# 48                   Antigua and Barbuda      75.00
# ...                                  ...        ...
# 2148  Venezuela (Bolivarian Republic of)      74.05
# 2160                            Viet Nam      76.34
# 2172                               Yemen      65.31
# 2184                              Zambia      62.33
# 2196                            Zimbabwe      61.45
#
# [184 rows x 2 columns]

# %% [markdown]
# 2. Get some food-related common health indices which includes 'overweight','blood_pressure','blood_glucose','cholesterol' from the data download from WHO website. The data shows the percentage of total population in a country who suffer from these common diseases.

# %%
data_overweight= pd.read_csv('data/data_health/data_overweight.csv')
data_overweight.rename(columns={'First Tooltip':'Overweight(%)'},inplace=True)
data=pd.merge(data_lifespan,data_overweight[['Location','Overweight(%)']],on='Location')

# %%
data_sub= pd.read_csv('data/data_health/data_blood_glucose.csv')
data_sub.rename(columns={'First Tooltip':'High Blood Glucose(%)'},inplace=True)
data=pd.merge(data,data_sub[['Location','High Blood Glucose(%)']],on='Location')

# %%
data_sub= pd.read_csv('data/data_health/data_blood_pressure.csv')
data_sub.rename(columns={'First Tooltip':'High Blood Pressure(%)'},inplace=True)
data=pd.merge(data,data_sub[['Location','High Blood Pressure(%)']],on='Location')

# %%
data_sub= pd.read_csv('data/data_health/data_cholesterol.csv')
data_sub.rename(columns={'First Tooltip':'High Cholesterol(%)'},inplace=True)
data=pd.merge(data,data_sub[['Location','High Cholesterol(%)']],on='Location')

# %% [markdown]
# 3. Get some NCD data (non-communicable diseases, including Malignant neoplasms, Diabetes mellitus, Cardiovascular diseases, Chronic obstructive pulmonary disease) in different countries. NCD death probability means the probability of a person will die due to non communicable disease.

# %%
data_sub= pd.read_csv('data/data_health/data_NCD_death.csv')
data_sub.rename(columns={'First Tooltip':'NCD death probability(%)'},inplace=True)
data=pd.merge(data,data_sub[['Location','NCD death probability(%)']],on='Location')

# %% [markdown]
# 4. Get the death rate due to some specific disease types in a country. We only find the number of death in 2016 so we also get the population in different countries in 2016 in order to get death rate.

# %%
data_disease= pd.read_csv('data/data_health/data_disease_death.csv')
data_disease = data_disease[['Location','Dim2','First Tooltip']]
data_disease
# Out:
#         Location                                   Dim2  First Tooltip
# 0    Afghanistan                    Malignant neoplasms          19965
# 1    Afghanistan                      Diabetes mellitus           7056
# 2    Afghanistan                Cardiovascular diseases          51244
# 3    Afghanistan  Chronic obstructive pulmonary disease           6715
# 4        Albania                    Malignant neoplasms           5138
# ..           ...                                    ...            ...
# 731       Zambia  Chronic obstructive pulmonary disease           1910
# 732     Zimbabwe                    Malignant neoplasms           8872
# 733     Zimbabwe                      Diabetes mellitus           3590
# 734     Zimbabwe                Cardiovascular diseases          14184
# 735     Zimbabwe  Chronic obstructive pulmonary disease           2970
#
# [736 rows x 3 columns]

# %%
data_pop= pd.read_csv('data/data_health/data_population.csv')
data_pop = data_pop[data_pop['Time']==2016][['Location','PopTotal']]

# %%
data_disease= pd.merge(data_disease,data_pop,on='Location')
data_disease['disease(%)']=data_disease['First Tooltip']/data_disease['PopTotal']/10

# %%
diseases = ['Malignant neoplasms','Diabetes mellitus','Cardiovascular diseases','Chronic obstructive pulmonary disease']
for d in diseases:
    data_sub=data_disease.loc[data_disease['Dim2']==d]
    data_sub.rename(columns={'disease(%)':d+' death(%)'},inplace=True)
    data=pd.merge(data,data_sub[['Location',d+' death(%)']],on='Location')
data.rename(columns={'Cardiovascular diseases death(%)':'Cardiovascular death(%)','Chronic obstructive pulmonary disease death(%)':'Chronic obstructive pulmonary death(%)'},inplace=True)

# %% [markdown]
# 5. Get GDP per capita of different countries because we think it is a very important factor for some health indices. For example the life span in wealthy country is usually higher than poorer one(it can be showed in the correlation table below). So we decide to group countries by GDP per capita level and get more reliable food and health relationship in different groupes.

# %%
data_gdp=pd.read_csv('data/GDP_per_capita.csv',header=1,skiprows=1)
data_gdp=data_gdp[['Country Name','2016']]
data_gdp.rename(columns={'Country Name':'Location','2016':'GDP per capita($)'},inplace=True)

# %%
data_health = pd.read_csv('data/health.csv')
data_health_wealth = pd.merge(data_health,data_gdp,on='Location')
data_health_wealth.drop(columns='Unnamed: 0',inplace=True)

# %%
col = ['Overweight(%)','High Blood Glucose(%)','High Blood Pressure(%)','High Cholesterol(%)']
for c in col:
    data_health_wealth[c]=data_health_wealth[c].str.split('[',expand=True)[0].astype('float')
data_health_wealth
# Out:
#                 Location  Life span  Overweight(%)  High Blood Glucose(%)  \
# 0            Afghanistan      62.69           23.0                   11.9
# 1                Albania      76.37           57.7                    7.4
# 2                Algeria      76.36           62.0                   12.4
# 3                 Angola      62.63           27.5                    8.2
# 4    Antigua and Barbuda      75.00           48.0                   11.5
# ..                   ...        ...            ...                    ...
# 151              Uruguay      77.06           62.9                    9.5
# 152           Uzbekistan      72.33           48.2                   10.6
# 153              Vanuatu      71.98           57.1                   15.9
# 154               Zambia      62.33           27.8                    6.6
# 155             Zimbabwe      61.45           38.2                    7.1
#
#      High Blood Pressure(%)  High Cholesterol(%)  NCD death probability(%)  \
# 0                      30.6                 21.9                      29.8
# 1                      29.0                 45.3                      17.0
# 2                      25.1                 39.4                      14.2
# 3                      29.7                 30.9                      16.5
# 4                      23.4                 43.0                      22.6
# ..                      ...                  ...                       ...
# 151                    20.7                 42.3                      16.7
# 152                    25.6                 26.8                      24.5
# 153                    24.2                 37.6                      23.3
# 154                    27.1                 27.7                      17.9
# 155                    28.2                 23.9                      19.3
#
#      Malignant neoplasms death(%)  Diabetes mellitus death(%)  \
# 0                        0.056425                    0.019942
# 1                        0.178006                    0.005820
# 2                        0.062060                    0.020690
# 3                        0.029314                    0.008248
# 4                        0.141769                    0.056073
# ..                            ...                         ...
# 151                      0.251596                    0.027277
# 152                      0.044037                    0.018173
# 153                      0.071858                    0.028384
# 154                      0.049036                    0.009014
# 155                      0.063234                    0.025587
#
#      Cardiovascular death(%)  Chronic obstructive pulmonary death(%)  \
# 0                   0.144826                                0.018978
# 1                   0.517248                                0.030730
# 2                   0.170581                                0.014710
# 3                   0.078152                                0.012489
# 4                   0.224291                                0.029623
# ..                       ...                                     ...
# 151                 0.269644                                0.078005
# 152                 0.314604                                0.011303
# 153                 0.158088                                0.031258
# 154                 0.076286                                0.011672
# 155                 0.101095                                0.021168
#
#      GDP per capita($)
# 0           547.228110
# 1          4124.108543
# 2          3948.811897
# 3          3506.072885
# 4         15494.305472
# ..                 ...
# 151       15387.144030
# 152        2567.799418
# 153        2830.965284
# 154        1280.578447
# 155        1464.583529
#
# [156 rows x 12 columns]

# %%
data_health_wealth.to_csv('./data/health_wealth.csv')

# %%
data_health_wealth.corr()
# Out:
#                                         Life span  Overweight(%)  \
# Life span                                1.000000       0.644024
# Overweight(%)                            0.644024       1.000000
# High Blood Glucose(%)                    0.007472       0.440353
# High Blood Pressure(%)                  -0.684095      -0.509246
# High Cholesterol(%)                      0.822280       0.646648
# NCD death probability(%)                -0.695510      -0.309185
# Malignant neoplasms death(%)             0.658405       0.423001
# Diabetes mellitus death(%)               0.060981       0.164485
# Cardiovascular death(%)                  0.309859       0.313552
# Chronic obstructive pulmonary death(%)   0.448686       0.139346
# GDP per capita($)                        0.648762       0.377287
#
#                                         High Blood Glucose(%)  \
# Life span                                            0.007472
# Overweight(%)                                        0.440353
# High Blood Glucose(%)                                1.000000
# High Blood Pressure(%)                              -0.071915
# High Cholesterol(%)                                  0.014533
# NCD death probability(%)                             0.319658
# Malignant neoplasms death(%)                        -0.330510
# Diabetes mellitus death(%)                           0.334904
# Cardiovascular death(%)                             -0.132621
# Chronic obstructive pulmonary death(%)              -0.248565
# GDP per capita($)                                   -0.229695
#
#                                         High Blood Pressure(%)  \
# Life span                                            -0.684095
# Overweight(%)                                        -0.509246
# High Blood Glucose(%)                                -0.071915
# High Blood Pressure(%)                                1.000000
# High Cholesterol(%)                                  -0.548030
# NCD death probability(%)                              0.596002
# Malignant neoplasms death(%)                         -0.244812
# Diabetes mellitus death(%)                           -0.093056
# Cardiovascular death(%)                               0.150414
# Chronic obstructive pulmonary death(%)               -0.308920
# GDP per capita($)                                    -0.557749
#
#                                         High Cholesterol(%)  \
# Life span                                          0.822280
# Overweight(%)                                      0.646648
# High Blood Glucose(%)                              0.014533
# High Blood Pressure(%)                            -0.548030
# High Cholesterol(%)                                1.000000
# NCD death probability(%)                          -0.550841
# Malignant neoplasms death(%)                       0.692615
# Diabetes mellitus death(%)                         0.087813
# Cardiovascular death(%)                            0.373625
# Chronic obstructive pulmonary death(%)             0.434463
# GDP per capita($)                                  0.740194
#
#                                         NCD death probability(%)  \
# Life span                                              -0.695510
# Overweight(%)                                          -0.309185
# High Blood Glucose(%)                                   0.319658
# High Blood Pressure(%)                                  0.596002
# High Cholesterol(%)                                    -0.550841
# NCD death probability(%)                                1.000000
# Malignant neoplasms death(%)                           -0.392777
# Diabetes mellitus death(%)                              0.177982
# Cardiovascular death(%)                                 0.122294
# Chronic obstructive pulmonary death(%)                 -0.263336
# GDP per capita($)                                      -0.652555
#
#                                         Malignant neoplasms death(%)  \
# Life span                                                   0.658405
# Overweight(%)                                               0.423001
# High Blood Glucose(%)                                      -0.330510
# High Blood Pressure(%)                                     -0.244812
# High Cholesterol(%)                                         0.692615
# NCD death probability(%)                                   -0.392777
# Malignant neoplasms death(%)                                1.000000
# Diabetes mellitus death(%)                                  0.025395
# Cardiovascular death(%)                                     0.704076
# Chronic obstructive pulmonary death(%)                      0.637186
# GDP per capita($)                                           0.496742
#
#                                         Diabetes mellitus death(%)  \
# Life span                                                 0.060981
# Overweight(%)                                             0.164485
# High Blood Glucose(%)                                     0.334904
# High Blood Pressure(%)                                   -0.093056
# High Cholesterol(%)                                       0.087813
# NCD death probability(%)                                  0.177982
# Malignant neoplasms death(%)                              0.025395
# Diabetes mellitus death(%)                                1.000000
# Cardiovascular death(%)                                   0.031192
# Chronic obstructive pulmonary death(%)                    0.197331
# GDP per capita($)                                        -0.092283
#
#                                         Cardiovascular death(%)  \
# Life span                                              0.309859
# Overweight(%)                                          0.313552
# High Blood Glucose(%)                                 -0.132621
# High Blood Pressure(%)                                 0.150414
# High Cholesterol(%)                                    0.373625
# NCD death probability(%)                               0.122294
# Malignant neoplasms death(%)                           0.704076
# Diabetes mellitus death(%)                             0.031192
# Cardiovascular death(%)                                1.000000
# Chronic obstructive pulmonary death(%)                 0.333768
# GDP per capita($)                                      0.048795
#
#                                         Chronic obstructive pulmonary death(%)  \
# Life span                                                             0.448686
# Overweight(%)                                                         0.139346
# High Blood Glucose(%)                                                -0.248565
# High Blood Pressure(%)                                               -0.308920
# High Cholesterol(%)                                                   0.434463
# NCD death probability(%)                                             -0.263336
# Malignant neoplasms death(%)                                          0.637186
# Diabetes mellitus death(%)                                            0.197331
# Cardiovascular death(%)                                               0.333768
# Chronic obstructive pulmonary death(%)                                1.000000
# GDP per capita($)                                                     0.350574
#
#                                         GDP per capita($)
# Life span                                        0.648762
# Overweight(%)                                    0.377287
# High Blood Glucose(%)                           -0.229695
# High Blood Pressure(%)                          -0.557749
# High Cholesterol(%)                              0.740194
# NCD death probability(%)                        -0.652555
# Malignant neoplasms death(%)                     0.496742
# Diabetes mellitus death(%)                      -0.092283
# Cardiovascular death(%)                          0.048795
# Chronic obstructive pulmonary death(%)           0.350574
# GDP per capita($)                                1.000000
